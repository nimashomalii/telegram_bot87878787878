# %%
# Step 1: Clone from GitHub (replace with your repo)
# !git clone https://github.com/YOUR_USERNAME/crypto-bot.git || true
# %cd crypto-bot

# %%
# Step 2: Install dependencies
# !pip install -q -r requirements.txt

# %%
# Step 3: Setup environment variables (user input)
import os
TELEGRAM_BOT_TOKEN = input("توکن ربات تلگرام را وارد کنید: ")
os.environ["TELEGRAM_BOT_TOKEN"] = TELEGRAM_BOT_TOKEN

# %%
# Step 4: Run the bot (stop cell to terminate)
# !python bot/main.py
